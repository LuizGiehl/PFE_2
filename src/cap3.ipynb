# %% [markdown]
# Capítulo 3
#
# Introdução a plotagem

# %%
import pandas as pd

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# 3.2 Matplotlib

# %% [markdown]
# importamos matplotlib.pyplot pois estamos importando apenas um subpacote com utilitários para plotagem

# %%
import matplotlib.pyplot as plt

dataset1 = anscombe[anscombe['dataset'] == 'I']
dataset2 = anscombe[anscombe['dataset'] == 'II']
dataset3 = anscombe[anscombe['dataset'] == 'III']
dataset4 = anscombe[anscombe['dataset'] == 'IV']

plt.plot(dataset1['x'], dataset1['y'])

# %%
plt.plot(dataset1['x'], dataset1['y'], 'o')

# %% [markdown]
# Por padrão o plt.plot desenha linhas, se quiser mudar para pontos basta passar o parâmetro 'o'

# %%
fig = plt.figure()

axesI = fig.add_subplot(2,2,1)
axesII = fig.add_subplot(2,2,2)
axesIII = fig.add_subplot(2,2,3)
axesIV = fig.add_subplot(2,2,4)

# %% [markdown]
# Estamos criando uma subplotagem, para que não seja nescessario criar uma plotagem diferente para um dos subconjuntos

# %%
axesI.plot(dataset1['x'], dataset1['y'], 'o')
axesII.plot(dataset2['x'], dataset2['y'], 'o')
axesIII.plot(dataset3['x'], dataset3['y'], 'o')
axesIV.plot(dataset4['x'], dataset4['y'], 'o')

# %% [markdown]
# adicionamos subconjuntos de dados nas plotagens

# %%
#acrescenta um título para cada plotagem
axesI.set_title("dataset_1")
axesII.set_title("dataset_2")
axesIII.set_title("dataset_3")
axesIV.set_title("dataset_4")

#define um rotulo para os eixos
for ax in [axesI, axesII, axesIII, axesIV]:
    ax.set_xlabel('Eixo X')
    ax.set_ylabel('Eixo Y')

#adiciona um título para toda a figura
fig.suptitle("Anscombe Data")

#ajeita os elementos de todo o layout
fig.tight_layout()

fig

# %% [markdown]
# 3.3 Gráficos estatísticos usando a matplotlib

# %% [markdown]
# Dados de gorjeta provenientes da biblioteca seaborn

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Univariado = uma única variável

# %% [markdown]
# 3.3.1.1 Histogramas

# %%
#cria figura e eixos
fig2 = plt.figure()
axes1 = fig2.add_subplot(1,1,1)

#craia o histograma
axes1.hist(tips['total_bill'], bins=10)

#adiciona título e rótulos
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig2.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\208972914.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()

# %% [markdown]
# Bivariado = duas variáveis

# %% [markdown]
# 3.3.2.1 Gráfico de dispersão
#
# Scatterplots, são usados quando uma variável contínua é plotada em relação a outra variável contínua

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)

axes1.scatter(tips['total_bill'], tips['tip'])

axes1.set_title('Scatterplot of Total Bill vs Tip ')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\3286305205.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   scatter_plot.show()

# %% [markdown]
# 3.3.2.2 Gráfico de caixa

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot(
    #o primeiro argumento de um gráfico de caixa é o dado,
    #pois estamos plotando várias porções de dados
    #temos que colocar cada porção em uma lista
    [tips[tips['sex'] == 'Female']['tip'],
     tips[tips['sex'] == 'Male']['tip']],
    #foi difícil mas consegui entender, o tips[tips['sex] == 'Female'] o tips da frente isola todos os sex female em um único dataframe p mesmo vale para o 'Male'

        #podemos passar um parâmetro labels opcional
        #para especificar um rótulo aos dados que passamos
     labels=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')

boxplot.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\2997899317.py:20: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   boxplot.show()

# %% [markdown]
# 3.3.3 Dados multivariados

# %% [markdown]
# É possivel plotar dados multivariados, porém pode ser complicado e muitas vezes confuso.
#
# Cada situação usará de diferentes formas para se plotar, mas deve tomar cuidado e atenção para ter certeza de que os dados vão estar claros

# %% [markdown]
# A metplotlib e o seaborn tem o próprio conjunto de paletas de corres para diferenciar os dados

# %%
#cria uma variável de cor baseada no sexo

def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1
    
tips['sex_color'] = tips['sex'].apply(recode_sex)

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],

    #define o tamanho dos pontos com base no tamanho dos grupos
    #multiplicamos os valores por 10 para deixar os pontos maiores e enfatizar as diferenças 
    s=tips['size'] * 10,

    #define a cor do sexo
    c=tips['sex_color'],

    #define o valor de alpha para que os pontos sejam mais transparentes
    alpha=0.5
)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\1565315381.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   scatter_plot.show()

# %% [markdown]
# 3.4 seaborn

# %% [markdown]
# 3.4.1 UNIVARIADOS

# %% [markdown]
# 3.4.1.1

# %%
#a função subplots cria a figure e já adiciona um subplot
#ao contrario da metplotlib que é nescessario criar uma figure para depois adicionar
hist, ax = plt.subplots()

#usa função distplot do seaborn para criar a plotagem
#o parâmetro kde (Kernel Density Estimate) faz aparecer a linha em curva
#edgecolor é um parâmetro referente as linhas, deixar em None remove
ax = sns.histplot(tips['total_bill'], kde=False, edgecolor=None)
ax.set_title('Total Bill Histogram with Density Plot')

plt.show()

# %% [markdown]
# A função que usaríamos no livro seria a distplot, porém ela vai ficar obsoleta e será trocada por displot e histplot
#
# PESQUISAR AS DIFERENÇAS DEPOIS

# %% [markdown]
# 3.4.1.2 Plotagem de Densidade (estimativa de densidade por Kernel)

# %%
den, ax = plt.subplots()
#parâmetro till faz com que a área seja preenchida
#bw_adjust ajusta a largura de banda kde, ou seja quanto menor o numero mais detalhado será o grafico
ax = sns.kdeplot(tips['total_bill'])

ax.set_title('Total Bill Density')
ax.set_xlabel('Total bill')
ax.set_ylabel('Unit Probability')

plt.show()

# %% [markdown]
# 3.4.1.3 Rug plot

# %%
hist_den_rug, ax = plt.subplots()

#para juntar os 3 vc cria um histograma com kde true e depois adiciona o rugplot com o mesmo conjunto de dados
ax = sns.histplot(tips['total_bill'], kde=True, edgecolor=None)
sns.rugplot(tips['total_bill'])

ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')

plt.show()

# %% [markdown]
# 3.4.1.4 Plotagem de contadores (plotagem de barras)

# %% [markdown]
# A plotagem de barras é usada com o intuito de contar variáveis discretas

# %%
count, ax = plt.subplots()

#ao passar uma coluna de dados do dataframe você deve especificar em qual eixo ela irá apareceer EX: x='day'
#se quiser que as barras fiquem coloridas precissa passar uma paleta de cores
#existem paletas do próprio seaborn mas caso queira você pode criar suas próprias
ax = sns.countplot(x='day', data=tips, palette='deep')

ax.set_title('Count of Days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\547712670.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='day', data=tips, palette='deep')

# %% [markdown]
# 3.4.2 DADOS BIVARIADOS

# %% [markdown]
# 3.4.2.1 Gráficos de dispersão

# %% [markdown]
# regplot vem junto uma linha de regressão

# %%
scatter, ax = plt.subplots()

#se passar o parâmetro fit_reg=False teremos apenas o gráfico de dispersão
ax = sns.regplot(data=tips, x='total_bill', y='tip', fit_reg=False)

ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %% [markdown]
# Também é possível usar lmplot para criar um gráfico de dispersão. A diferença é que lmplot cria uma figura, enquanto regplot cria eixos

# %%
fig = sns.lmplot(data=tips, x='total_bill', y='tip')
plt.show()

# %% [markdown]
# O joint plot cria um gráfico de dispersão com uma plotagem univariada em cada eixo

# %%
joint = sns.jointplot(data=tips, x='total_bill', y='tip')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')

#adiciona um titulo e regula o texto pra não ficar em cima do gráfico
joint.figure.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# 3.4.2.2 Plotagem hexbin

# %%
hexbin = sns.jointplot(data=tips, x='total_bill', y='tip', kind='hex')

hexbin.set_axis_labels(xlabel='Total bill', ylabel='Tip')
hexbin.figure.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# 3.4.2.3 Plotagem de densidade 2D

# %%
kde, ax = plt.subplots()
ax = sns.kdeplot(x=tips['total_bill'], y=tips['tip'], shade=True)


ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

kde_joint = sns.jointplot(data=tips, x='total_bill', y='tip', kind='kde', shade=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\327135451.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(x=tips['total_bill'], y=tips['tip'], shade=True)
# c:\Users\User\anaconda3\envs\pfe_certo\Lib\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %% [markdown]
# 3.4.2.4 Plotagem de barras

# %% [markdown]
# Por padrão barplot o estimator é = np.mean, mas você pode passar qualquer função para o parâmetro estimator

# %%
import numpy as np

bar, ax = plt.subplots()
ax = sns.barplot(data=tips, x='time', y='total_bill', palette='dark', estimator=np.median)

ax.set_title('Bar plot Of avarage total bill for time of day')
ax.set_xlabel('time of day')
ax.set_ylabel('Avarage total bill')

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\3728632760.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=tips, x='time', y='total_bill', palette='dark', estimator=np.median)

# %% [markdown]
# 3.4.2.5 Gráfico de caixa

# %%
box, ax = plt.subplots()
ax = sns.boxplot(data=tips, x='time', y='total_bill', palette='dark')

ax.set_title('Boxplt of total bill by time of day')
ax.set_title('Time of day')
ax.set_ylabel('Total bill')

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\2711838542.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=tips, x='time', y='total_bill', palette='dark')

# %% [markdown]
# 3.4.2.6 Plotagem de violino

# %% [markdown]
# A plotagem de violino pode plotar os mesmos dados que uma plotagem de caixa, mas com a diferença que ela mostra os dados de uma maneira mais clara e com menos chances de enganos

# %%
violion, ax = plt.subplots()
ax = sns.violinplot(data=tips, x='time', y='total_bill', palette='dark')

ax.set_title('violion plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total bill')

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\2788637287.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.violinplot(data=tips, x='time', y='total_bill', palette='dark')

# %% [markdown]
# 3.4.2.7 Relacionamento de pares

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)

pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.histplot, kde=True, edgecolor=None)

for ax in pair_grid.diag_axes:
    ax.set_ylim(0, 45)

plt.show()

# %% [markdown]
# 3.4.3 Dados multivariados

# %% [markdown]
# 3.4.3.1 Cores

# %%
violion, ax = plt.subplots()
ax = sns.violinplot(data=tips, x='time', y='total_bill',
                    hue='sex', split=True, palette='dark', inner='point')

plt.show()

# %%
scatter = sns.lmplot(data=tips, x='total_bill', y='tip',
                     hue='sex', fit_reg=False)

plt.show()

# %%
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# O parâmetro hue colori a plotagem de acordo com os dados que você passar, nestes exemplos passamos o conjunto 'sex' do dataframe tips.

# %% [markdown]
# 3.4.3.2 Tamanho e Formato

# %%
scatter = sns.lmplot(data=tips, x='total_bill', y='tip',
                     hue='sex', fit_reg=False,
                     scatter_kws={'s': 20})
#era pra mudar o tamnho de algumas bolinhas, MAS ESSA DESGRAÇA NÃO MUDA POR NADA VAI SE FODER
                     
plt.show()

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips,
                     fit_reg=False, hue='sex', markers=['o', '^'])

# %% [markdown]
# 3.4.3.3 Facetas

# %% [markdown]
# As facetas serve para fazer várias plotagens sobre uma variável de categoria.
#
# Elas facilitam a vida, ao invés de ter que criar varios subconjuntos e definir os eixos ela faz isso de forma automática.

# %%
anscombe_plot = sns.lmplot(data=anscombe, x='x', y='y',
                           fit_reg=False,
                           col='dataset', col_wrap=2)

# %% [markdown]
# Nem toda função de plotagem terá os parâmetro col e col_wrap, eles servem apenas para as plotagens em figuras, e a maioria são em eixos
#
# E ao invés disso, nós usamos FacetGrid que saberá sobre qual variável criar a faceta, e fornecer o código da plotagem individual de cada faceta

# %%
facet = sns.FacetGrid(tips, col='time')
#para cada valor de tempo plota um histograma do total da conta
facet.map(sns.histplot, 'total_bill', kde=True)
facet.map(sns.rugplot, 'total_bill')
facet.set(xlim=(0, 60), ylim=(0, 40))
plt.show()

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()

plt.show()

# %%
fig = sns.lmplot(data=tips, x='total_bill', y='tip', fit_reg=False,
                 hue='sex', col='day')

plt.show()

# %% [markdown]
# Outra coisa que podemos fazer é ter uma variável com faceta no eixo X e outra no eixo y passando o parâmetro row

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex',)
facet.map(plt.scatter, 'total_bill', 'tip')

plt.show()

# %%
facet = sns.catplot(data=tips, x='day', y='total_bill', hue='sex',
                       row='smoker', col='time', kind='violin')

# %% [markdown]
# 3.5 Objetos do Pandas
# -

# %% [markdown]
# Para criar plotagem usando o pandas basta passar: DataFrame.plot.TIPO_DA_PLOTAGEM ou Series.plot.TIPO_DA_PLOTAGEM

# %% [markdown]
# 3.5.1 Histogramas

# %%
#em Series
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

plt.show()

# %%
#em DataFrame
fig, ax = plt.subplots()
#alpha define um canal de transparência
#ax=ax joga para o mesmo local do subplot
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

plt.show()

# %% [markdown]
# 3.5.2 Plotagem de densidade

# %%
fig, ax = plt.subplots()
ax = tips['tip'].plot.kde()

plt.show()

# %% [markdown]
# 3.5.3 Gráfico de dispersão

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

plt.show()

# %% [markdown]
# 3.5.4 Plotagem hexbin

# %%
fig, ax = plt.subplots()
#o tamanho pode ser ajustado com o parâmetro gridsize
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

plt.show()

# %% [markdown]
# 3.5.5 Gráfico de caixa

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

plt.show()

# %% [markdown]
# 3.6 Temas e estilos do seaborn
# -

# %%
sns.set_style('dark')
hexbin = sns.jointplot(data=tips, x='total_bill', y='tip', kind='hex', ax=ax)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19608\904781715.py:2: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   hexbin = sns.jointplot(data=tips, x='total_bill', y='tip', kind='hex', ax=ax)

# %%
fig, ax = plt.subplots()
ax = sns.violinplot(data=tips, x='time', y='total_bill',
                     hue='sex', split=True, palette='dark')
plt.show()

# %% [markdown]
# O código a seguir mostra todos os estilos

# %%
fig = plt.figure()
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(data=tips, x='time', y='total_bill', ax=ax)
        violin.set_title(style)

fig.tight_layout()
plt.show()
